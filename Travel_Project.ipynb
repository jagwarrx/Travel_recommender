# %%
import googlemaps
import pandas as pd
import requests
import numpy as np
import json, ast
import re
gmaps = googlemaps.Client(key="AIzaSyCebhjE2D3WjUVtCAqmK0c8bE0p9iAaJTM")
#                         AIzaSyAQsZlpcPh0pCRxVqj1xqpicWX7kpZ-czw
                          #AIzaSyBe8ca_GhENiWTS8oS90ZufBdyZkvh0Wys

# %%
all_waypoints = [ "Chettinadu Mansion, 11, A.R.Street, S.A.R.M. House ,Siva gangai dist., Kanadukathan, Tamil Nadu 630103",
                 "The Shore Temple, Mahabalipuram, Tamil Nadu 603104",
                "Sri Ranganathar Swamy Temple - Srirangam, Srirangam, Tiruchirappalli, Tamil Nadu 620006",
                "Brihadeeswara Temple, Membalam Road, Balaganapathy Nagar, Thanjavur, Tamil Nadu",
                    "Meenakshi Amman Temple, Madurai, Tamil Nadu",
                    "Vivekananda Rock Memorial, Kanyakumari, Tamil Nadu",
                    "Ooty Botanical Gardens, Ooty, Tamil Nadu",
                    "St Lourdes Church, Salai Road, Woraiyur, Tiruchirappalli, Tamil Nadu",
                 "Indira Gandhi National Park, Anamalai R.F., Tamil Nadu",
                    "Government Museum, Chennai, Tamil Nadu",
  "Gandhi Memorial Museum, Tallakulam, Madurai, Tamil Nadu"
                    "Airavatesvara Temple, Gurunathan Pillai Colony, Darasuram, Kumbakonam, Tamil Nadu",
                   "The Shore Temple, Mahabalipuram, Tamil Nadu 603104",
                "Sri Ranganathar Swamy Temple - Srirangam, Srirangam, Tiruchirappalli, Tamil Nadu 620006",
                "Brihadeeswara Temple, Membalam Road, Balaganapathy Nagar, Thanjavur, Tamil Nadu",
                    "Meenakshi Amman Temple, Madurai, Tamil Nadu",
                    "Vivekananda Rock Memorial, Kanyakumari, Tamil Nadu",
                    "Ooty Botanical Gardens, Ooty, Tamil Nadu",
                    "St Lourdes Church, Salai Road, Woraiyur, Tiruchirappalli, Tamil Nadu",
                 "Indira Gandhi National Park, Anamalai R.F., Tamil Nadu",
                    "Government Museum, Chennai, Tamil Nadu",
  "Gandhi Memorial Museum, Tallakulam, Madurai, Tamil Nadu"
                 ]

# %%
waypoint_distances
# Out:
# {frozenset({'Indira Gandhi National Park, Anamalai R.F., Tamil Nadu',
#             'Sri Ranganathar Swamy Temple - Srirangam, Srirangam, Tiruchirappalli, Tamil Nadu 620006'}): 276361,
#  frozenset({'St Lourdes Church, Salai Road, Woraiyur, Tiruchirappalli, Tamil Nadu',
#             'The Shore Temple, Mahabalipuram, Tamil Nadu 603104'}): 287324,
#  frozenset({'Brihadeeswara Temple, Membalam Road, Balaganapathy Nagar, Thanjavur, Tamil Nadu',
#             'Sri Ranganathar Swamy Temple - Srirangam, Srirangam, Tiruchirappalli, Tamil Nadu 620006'}): 61371,
#  frozenset({'Sri Ranganathar Swamy Temple - Srirangam, Srirangam, Tiruchirappalli, Tamil Nadu 620006',
#             'The Shore Temple, Mahabalipuram, Tamil Nadu 603104'}): 280592,
#  frozenset({'Indira Gandhi National Park, Anamalai R.F., Tamil Nadu',
#             'St Lourdes Church, Salai Road, Woraiyur, Tiruchirappalli, Tamil Nadu'}): 272225,
# ...

# %%
waypoint_type
# Out:
# {'Airavatesvara Temple, Gurunathan Pillai Colony, Darasuram, Kumbakonam, Tamil Nadu': ['hindu_temple',
#   'place_of_worship',
#   'point_of_interest',
#   'establishment'],
#  'Brihadeeswara Temple, Membalam Road, Balaganapathy Nagar, Thanjavur, Tamil Nadu': ['hindu_temple',
#   'place_of_worship',
#   'point_of_interest',
#   'establishment'],
#  'Chettinadu Mansion, 11, A.R.Street, S.A.R.M. House ,Siva gangai dist., Kanadukathan, Tamil Nadu 630103': ['lodging',
#   'point_of_interest',
#   'establishment'],
#  'Gandhi Memorial Museum, Tallakulam, Madurai, Tamil Nadu': ['museum',
#   'point_of_interest',
#   'establishment'],
#  'Government Museum, Chennai, Tamil Nadu': ['museum',
#   'point_of_interest',
#   'establishment'],
#  'Indira Gandhi National Park, Anamalai R.F., Tamil Nadu': ['park',
#   'point_of_interest',
#   'establishment'],
#  'Meenakshi Amman Temple, Madurai, Tamil Nadu': ['hindu_temple',
#   'place_of_worship',
#   'point_of_interest',
#   'establishment'],
# ...

# %%
from itertools import combinations

waypoint_distances = {}
waypoint_durations = {}

for (waypoint1, waypoint2) in combinations(all_waypoints, 2):
    try:
        route = gmaps.distance_matrix(origins=[waypoint1],
                                      destinations=[waypoint2],
                                      mode="driving", # Change this to "walking" for walking directions,
                                                      # "bicycling" for biking directions, etc.
                                      language="English",
                                      units="metric")

        # "distance" is in meters
        distance = route["rows"][0]["elements"][0]["distance"]["value"]

        # "duration" is in seconds
        duration = route["rows"][0]["elements"][0]["duration"]["value"]

        waypoint_distances[frozenset([waypoint1, waypoint2])] = distance
        waypoint_durations[frozenset([waypoint1, waypoint2])] = duration
        
    except Exception as e:
        print("Error with finding the route between %s and %s." % (waypoint1, waypoint2))

# %%
def find_rating_type(place):
    place.replace (" ", "+")
    key = "AIzaSyBW_I3Y5rNNzBZEeryGcwRGjBRPbPPX79I"
    response = requests.get('https://maps.googleapis.com/maps/api/place/textsearch/json?query='+ place + '&key=' + key)
    json_data = json.loads(response.text)
    print(json_data)
    try:
        loc = json_data['results'][0]['geometry']['location']
    except IndexError:
        loc = ['None']
    loc = ast.literal_eval(json.dumps(loc))
    try:
        rating = json_data['results'][0]['rating']
    except KeyError or IndexError:
        rating = -1
    try:    
        place_type = json_data['results'][0]['types']
    #if(re.search('[a-zA-Z]', str(place_type))):
    #   pass
    except IndexError:
        place_type = ['None']
    place_type = ast.literal_eval(json.dumps(place_type))
    return rating, place_type, loc

# %%
waypoint_rating = {}
waypoint_type = {}
waypoint_loc = {}
for i in all_waypoints:
    waypoint_rating[i], waypoint_type[i], waypoint_loc[i]  = find_rating_type(i)
    print(i)
# Out:
# {u'status': u'OK', u'html_attributions': [], u'results': [{u'rating': 3.8, u'name': u'Chettinadu Mansion', u'reference': u'CnRmAAAAm2jrEALlcqKNdBVxTj4bAoB57egkBo8HI__mHtx0KGFoqG9PiZI8YuXrRSa61yfuTqRNPYIPfzd3WaqkET1SW8vxIDudkCDa_6QxH1U_yo4wWZ5jn5gGt7mLkcfybt8ud8yUGLfKzCMhuSSEM5RyQxIQYzT07easfOg8LIUzZ_PtVBoUzG2eTxJ4AgULTRYRkK8zqr6JnMo', u'geometry': {u'location': {u'lat': 10.174459, u'lng': 78.781429}, u'viewport': {u'northeast': {u'lat': 10.1744598, u'lng': 78.7815135}, u'southwest': {u'lat': 10.1744586, u'lng': 78.7813855}}}, u'place_id': u'ChIJB6Er2TlkADsR7xotrvJc7JU', u'photos': [{u'photo_reference': u'CoQBdwAAAO9rAZYIBC26AnPzeehn60KEoMsbKCch2kIBXt8omp6aS2wS0iPjic3PWQqG-8m9-9Fj1_iKP-xiipKvrjT4kl_LEYZ4Le7H-gVMoizH4hhhLDfHNjPU4206yJCjTGbkDCPeSMpjuRDilJS438H7Km7qTM5UMu1as0CP0d9ThESNEhCoNIsYvf13fT13t9bzbq2NGhRwSBwlaW9eDnOoJ55olsqFxN1GfA', u'width': 3264, u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/117304621963453332192/photos">David Comin Roig</a>'], u'height
# ...

# %%
waypoint_type
# Out:
# {'Airavatesvara Temple, Gurunathan Pillai Colony, Darasuram, Kumbakonam, Tamil Nadu': ['hindu_temple',
#   'place_of_worship',
#   'point_of_interest',
#   'establishment'],
#  'Brihadeeswara Temple, Membalam Road, Balaganapathy Nagar, Thanjavur, Tamil Nadu': ['hindu_temple',
#   'place_of_worship',
#   'point_of_interest',
#   'establishment'],
#  'Chettinadu Mansion, 11, A.R.Street, S.A.R.M. House ,Siva gangai dist., Kanadukathan, Tamil Nadu 630103': ['lodging',
#   'point_of_interest',
#   'establishment'],
#  'Gandhi Memorial Museum, Tallakulam, Madurai, Tamil Nadu': ['museum',
#   'point_of_interest',
#   'establishment'],
#  'Government Museum, Chennai, Tamil Nadu': ['museum',
#   'point_of_interest',
#   'establishment'],
#  'Indira Gandhi National Park, Anamalai R.F., Tamil Nadu': ['park',
#   'point_of_interest',
#   'establishment'],
#  'Meenakshi Amman Temple, Madurai, Tamil Nadu': ['hindu_temple',
#   'place_of_worship',
#   'point_of_interest',
#   'establishment'],
# ...

# %%
str(waypoint_type[waypoint1]).replace(",","-") + ","
# Out:
# "['place_of_worship'- 'hindu_temple'- 'point_of_interest'- 'establishment'],"

# %%
json_data['results'][0]['types']
# Out:
# ['lodging', 'point_of_interest', 'establishment']

# %%
   for (waypoint1, waypoint2) in waypoint_distances.keys():
        print(waypoint1, waypoint2)
# Out:
# ('Indira Gandhi National Park, Anamalai R.F., Tamil Nadu', 'Sri Ranganathar Swamy Temple - Srirangam, Srirangam, Tiruchirappalli, Tamil Nadu 620006')
# ('St Lourdes Church, Salai Road, Woraiyur, Tiruchirappalli, Tamil Nadu', 'The Shore Temple, Mahabalipuram, Tamil Nadu 603104')
# ('Brihadeeswara Temple, Membalam Road, Balaganapathy Nagar, Thanjavur, Tamil Nadu', 'Sri Ranganathar Swamy Temple - Srirangam, Srirangam, Tiruchirappalli, Tamil Nadu 620006')
# ('Sri Ranganathar Swamy Temple - Srirangam, Srirangam, Tiruchirappalli, Tamil Nadu 620006', 'The Shore Temple, Mahabalipuram, Tamil Nadu 603104')
# ('Indira Gandhi National Park, Anamalai R.F., Tamil Nadu', 'St Lourdes Church, Salai Road, Woraiyur, Tiruchirappalli, Tamil Nadu')
# ('St Lourdes Church, Salai Road, Woraiyur, Tiruchirappalli, Tamil Nadu', 'Sri Ranganathar Swamy Temple - Srirangam, Srirangam, Tiruchirappalli, Tamil Nadu 620006')
# ...

# %%
with open("my-waypoints-dist-dur.csv", "w") as out_file:
    out_file.write("".join(["waypoint1,",
                              "waypoint1_rating,",
                              "waypoint1_type,",
                              "waypoint1_loc,",
                              "waypoint2,",
                              "waypoint2_rating,"
                              "waypoint2_type,"
                              "waypoint2_loc,",
                              "distance_m,",
                              "duration_s"
                             ]))
    
    for (waypoint1, waypoint2) in waypoint_distances.keys():
        out_file.write("\n" +
                       " ".join([ str(waypoint1.replace(",","-"))+",",
                                  str(waypoint_rating[waypoint1])+",",
                                  str(waypoint_type[waypoint1]).replace(",",";") + ",",
                                 str(waypoint_loc[waypoint1]).replace(",",";")+",", 
                                 str(waypoint2.replace(",","-"))+",",
                                  str(waypoint_rating[waypoint2])+",",
                                  str(waypoint_type[waypoint2]).replace(",",";")+",",
                                 str(waypoint_loc[waypoint2]).replace(",",";")+",", 
                                 str(waypoint_distances[frozenset([waypoint1, waypoint2])])+",",
                                  str(waypoint_durations[frozenset([waypoint1, waypoint2])])
                                 ]))

# %%
df = pd.read_csv('my-waypoints-dist-dur.csv')
len(df)
df
# Out:
#                                             waypoint1  waypoint1_rating  \
# 0   Indira Gandhi National Park- Anamalai R.F.- Ta...              -1.0
# 1   St Lourdes Church- Salai Road- Woraiyur- Tiruc...               4.7
# 2   Brihadeeswara Temple- Membalam Road- Balaganap...               4.7
# 3   Sri Ranganathar Swamy Temple - Srirangam- Srir...               4.7
# 4   Indira Gandhi National Park- Anamalai R.F.- Ta...              -1.0
# 5   St Lourdes Church- Salai Road- Woraiyur- Tiruc...               4.7
# 6   Gandhi Memorial Museum- Tallakulam- Madurai- T...               4.2
# 7   Sri Ranganathar Swamy Temple - Srirangam- Srir...               4.7
# 8              Government Museum- Chennai- Tamil Nadu               4.1
# 9   Vivekananda Rock Memorial- Kanyakumari- Tamil ...               4.6
# 10  Vivekananda Rock Memorial- Kanyakumari- Tamil ...               4.6
# 11  Airavatesvara Temple- Gurunathan Pillai Colony...               4.6
# ...

# %%
df.describe()
# Out:
#        waypoint1_rating  waypoint2_rating     distance_m    duration_s
# count         66.000000         66.000000      66.000000     66.000000
# mean           3.707576          4.259091  291555.893939  17903.196970
# std            1.902412          0.980263  164517.301734   9193.110573
# min           -1.000000         -1.000000    6798.000000   1115.000000
# 25%            4.100000          4.300000  162636.000000   9367.000000
# 50%            4.600000          4.500000  287105.000000  19442.500000
# 75%            4.700000          4.600000  387295.000000  23618.000000
# max            4.700000          4.700000  708236.000000  37245.000000

# %%
import random

def compute_fitness(solution):
    """
        This function returns the total distance traveled on the current road trip.
        
        The genetic algorithm will favor road trips that have shorter
        total distances traveled.
    """
    
    solution_fitness = 0.0
    
    for index in range(len(solution)):
        waypoint1 = solution[index - 1]
        waypoint2 = solution[index]
        solution_fitness += waypoint_distances[frozenset([waypoint1, waypoint2])]
        
    return solution_fitness

def generate_random_agent():
    """
        Creates a random road trip from the waypoints.
    """
    
    new_random_agent = list(all_waypoints)
    random.shuffle(new_random_agent)
    return tuple(new_random_agent)

def mutate_agent(agent_genome, max_mutations=3):
    """
        Applies 1 - `max_mutations` point mutations to the given road trip.
        
        A point mutation swaps the order of two waypoints in the road trip.
    """
    
    agent_genome = list(agent_genome)
    num_mutations = random.randint(1, max_mutations)
    
    for mutation in range(num_mutations):
        swap_index1 = random.randint(0, len(agent_genome) - 1)
        swap_index2 = swap_index1

        while swap_index1 == swap_index2:
            swap_index2 = random.randint(0, len(agent_genome) - 1)

        agent_genome[swap_index1], agent_genome[swap_index2] = agent_genome[swap_index2], agent_genome[swap_index1]
            
    return tuple(agent_genome)

def shuffle_mutation(agent_genome):
    """
        Applies a single shuffle mutation to the given road trip.
        
        A shuffle mutation takes a random sub-section of the road trip
        and moves it to another location in the road trip.
    """
    
    agent_genome = list(agent_genome)
    
    start_index = random.randint(0, len(agent_genome) - 1)
    length = random.randint(2, 20)
    
    genome_subset = agent_genome[start_index:start_index + length]
    agent_genome = agent_genome[:start_index] + agent_genome[start_index + length:]
    
    insert_index = random.randint(0, len(agent_genome) + len(genome_subset) - 1)
    agent_genome = agent_genome[:insert_index] + genome_subset + agent_genome[insert_index:]
    
    return tuple(agent_genome)

def generate_random_population(pop_size):
    """
        Generates a list with `pop_size` number of random road trips.
    """
    
    random_population = []
    for agent in range(pop_size):
        random_population.append(generate_random_agent())
    return random_population
    
def run_genetic_algorithm(generations=500, population_size=10):
    """
        The core of the Genetic Algorithm.
        
        `generations` and `population_size` must be a multiple of 10.
    """
    
    population_subset_size = int(population_size / 10)
    generations_10pct = int(generations / 10.)
    
    # Create a random population of `population_size` number of solutions.
    population = generate_random_population(population_size)

    # For `generations` number of repetitions...
    for generation in range(generations):
        
        # Compute the fitness of the entire current population
        population_fitness = {}

        for agent_genome in population:
            if agent_genome in population_fitness:
                continue

            population_fitness[agent_genome] = compute_fitness(agent_genome)

        # Take the top 10% shortest road trips and produce offspring each from them
        new_population = []
        for rank, agent_genome in enumerate(sorted(population_fitness,
                                                   key=population_fitness.get)[:population_subset_size]):
            
            if (generation % generations_10pct == 0 or generation == generations - 1) and rank == 0:
                print("Generation %d best: %d | Unique genomes: %d" % (generation,
                                                                       population_fitness[agent_genome],
                                                                       len(population_fitness)))
                print(agent_genome)
                print("")

            # Create 1 exact copy of each of the top road trips
            new_population.append(agent_genome)

            # Create 2 offspring with 1-3 point mutations
            for offspring in range(2):
                new_population.append(mutate_agent(agent_genome, 3))
                
            # Create 7 offspring with a single shuffle mutation
            for offspring in range(7):
                new_population.append(shuffle_mutation(agent_genome))

        # Replace the old population with the new population of offspring 
        for i in range(len(population))[::-1]:
            del population[i]

        population = new_population

# %%
run_genetic_algorithm(generations=500, population_size=10)
# Out:
# Generation 0 best: 3072141 | Unique genomes: 10
# ('Chettinadu Mansion, 11, A.R.Street, S.A.R.M. House ,Siva gangai dist., Kanadukathan, Tamil Nadu 630103', 'St Lourdes Church, Salai Road, Woraiyur, Tiruchirappalli, Tamil Nadu', 'Brihadeeswara Temple, Membalam Road, Balaganapathy Nagar, Thanjavur, Tamil Nadu', 'Ooty Botanical Gardens, Ooty, Tamil Nadu', 'Vivekananda Rock Memorial, Kanyakumari, Tamil Nadu', 'Sri Ranganathar Swamy Temple - Srirangam, Srirangam, Tiruchirappalli, Tamil Nadu 620006', 'Meenakshi Amman Temple, Madurai, Tamil Nadu', 'The Shore Temple, Mahabalipuram, Tamil Nadu 603104', 'Government Museum, Chennai, Tamil Nadu', 'Airavatesvara Temple, Gurunathan Pillai Colony, Darasuram, Kumbakonam, Tamil Nadu', 'Indira Gandhi National Park, Anamalai R.F., Tamil Nadu', 'Gandhi Memorial Museum, Tallakulam, Madurai, Tamil Nadu')
#
# Generation 50 best: 2114755 | Unique genomes: 6
# ...

# %%
find_rating_type("Sri Ranganathar Swamy Temple - Srirangam, Srirangam, Tiruchirappalli, Tamil Nadu 620006")
# Out:
# {u'status': u'OK', u'html_attributions': [], u'results': [{u'rating': 4.7, u'name': u'Sri Ranganathar Swamy Temple - Srirangam', u'reference': u'CoQBfAAAAD2kemSHCtn_cSXSWeAOWkl3UyXpGUQSjJ232BjX8fUNdeb6JVqW2z59pCSJMc965Z3YM5ym-wi6DhTg-VuUK1_7locQZDPh4h7qg9bWM16EHAyJbCJXH98ggQYUoVJLi56E5jvQXpm98R4E5NWxDgPexRCM40JjBecqL6ukO9GQEhCLVAzQnv2dDz3vYedvVtU6GhS9vXBcDO5NY-wdilgTtpPhBl_VWA', u'geometry': {u'location': {u'lat': 10.8620434, u'lng': 78.6902175}, u'viewport': {u'northeast': {u'lat': 10.86606795, u'lng': 78.69185359999999}, u'southwest': {u'lat': 10.85870535, u'lng': 78.68912999999999}}}, u'opening_hours': {u'weekday_text': [], u'open_now': False}, u'place_id': u'ChIJiYz963f2qjsRbEwLpgo1fcU', u'photos': [{u'photo_reference': u'CoQBcwAAAC2RqicWxkMFPffezkdJ_itFW53EKu3tPtAlVqzbuyksz5wFiw7S5YEag_O653l5exTngvpO7zHRGsaau--CNvbwafOYwD1PO6PavMaOknvY8XAuEaOU0VqDSbhQzFwrT9f6wZbfkkUIpriwQkG6LK2ZrCx9JyqpKd5CfcxZX31hEhC1v7ZXZVyMrQ_DEr-a-1pFGhQY1SiMDTmtD_9eCMBlD1IP67Mvlg', u'width': 2048, u'html_at
# ...

# %%
place_type = ['church', 'place_of_worship', 'point_of_interest', 'establishment']
if(re.search('[a-zA-Z]', str(place_type))):
    pass
else:
    place_type = ['None']

# %%
df['waypoint1_type']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-40fcb5a41d93> in <module>()
# ----> 1 df['waypoint1_type']
#       2
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1348         res = cache.get(item)
# ...

# %%
# USING GOOG MAPS API

origin = "The Shore Temple, Mahabalipuram, Tamil Nadu 603104"
dest = "Airavatesvara Temple, Gurunathan Pillai Colony, Darasuram, Kumbakonam, Tamil Nadu"
waypoints = "Chettinadu Mansion, 11, A.R.Street, S.A.R.M. House ,Siva gangai dist., Kanadukathan, Tamil Nadu 630103"
origin.replace(" ", "+")
dest.replace(" ", "+")
waypoints.replace(" ", "+")
resp = requests.get('http://maps.googleapis.com/maps/api/directions/json?origin='+origin+'&destination='+dest+'&waypoints=optimize:true|'+ waypoints +
'&mode:driving&key:AIzaSyCebhjE2D3WjUVtCAqmK0c8bE0p9iAaJTM')
json_data = json.loads(resp.text)
print(json_data)
# Out:
# {u'routes': [{u'overview_polyline': {u'points': u'gb_lA{mnhNzBlh@kWlc@pLzs@pJrt@sq@`_BtDzcCcBlvBfsAxrEpGfwB|]vY`j@fyBzh@ty@`eChz@jeBtw@~N`vAzl@hTwG`i@mWzeAxRhrByPp{A`WpsDnSn]va@nPzhBt`AjmAhiAlnB~wA|{EzvCrzFrlBn|@pkApmDxyCrgCdj@rkAcNzvAfo@r_DbxEliBdxDjcAvvBhtAtoAndBznAb_AuDjzA~d@tRbUaDzjAjw@tn@rmBtaAxaG~wC|aE`hChsChoBhkE~{AzkBxPvjCrr@`{AjhAbb@rq@`bAnTnbB`p@v{@rf@rf@tiB|n@xn@tiAaAfx@aKzm@fZhiB`\\xqBvmAvK~n@n^jRnbDfm@|aFpfBryKfuGfqCryD`rAv~Av`B~nAliAxb@b\\bdAtQvcAkEnlArGxQnZbh@xyAt`Cv~B|vDnn@deCxpB|`BhdCpyBnlFvcBn~BtxBdiBd`CfxAvyBbxB`nC|aBbkBpjDp{C|kB|w@zjA|IneA|qAr}CbkDj{Hh`GzeDpmBnkBlx@`tBdLtmArFlhCzf@p{IfwDplBtnAz`Bf_@`bCbcAtoBn[vuFtaAbyBhf@rlB|{@x}D|hCtqCdwAjtD`z@rbAf{Aj|@`[vo@fg@lmBhk@xgBjiAxnARru@wZnyG`HziAxS|ZlWtIzr@rSoPnaBe\\fhHcmBncCi}@dpE}l@`uEgt@xm@At}@sv@~hAcYtgAmv@dq@ud@|mCzCjaBm]riA`OjaDiNtlAdMhuAcK`bCoOplAgQhaC~BzgCwc@jvCpQtrCfA`sB~pAbiAlD|XcAlp@~RrnAqC|qBtRba@nx@n|@dNjo@lTxj@yAf`AwR`b@rYt~@}Px~Aah@d{Cgy@tWmSd[Fjb@Fz^}d@`Aq`@~]}Qw^dUkC`a@_^ha@{c@OwWz@oaBtx@_rA`RwbBlk@my@h
# ...
